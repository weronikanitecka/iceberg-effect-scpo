# %%
from pathlib import Path

# Root
ROOT = Path(__file__).resolve().parents[1]

# Data directories
DATA_RAW       = ROOT / "data" / "raw"
DATA_INTERIM   = ROOT / "data" / "interim"
DATA_PROCESSED = ROOT / "data" / "processed"

# Results
RESULTS_P1 = ROOT / "results" / "phase1"
RESULTS_P2 = ROOT / "results" / "phase2"

# Figures
FIGURES_P1 = ROOT / "figures" / "phase1"
FIGURES_P2 = ROOT / "figures" / "phase2"

# ACS year
ACS_YEAR = 2022

# Policy control constants
BORDER_STATES = {"TX", "CA", "AZ", "NM"}

STATE_287G = {
    "AL","AZ","AR","CO","FL","GA","ID","IN","IA","KS","KY","LA",
    "MD","MI","MS","MO","MT","NE","NV","NC","OH","OK","SC","TN",
    "TX","UT","VA","WV","WY"
}

SANCTUARY = {"CA","CO","CT","IL","MA","NJ","NY","OR","RI","VT","WA","DC"}

# State crosswalks
STATE_ABBR_TO_FIPS = {
    "AL":"01","AK":"02","AZ":"04","AR":"05","CA":"06","CO":"08","CT":"09",
    "DE":"10","DC":"11","FL":"12","GA":"13","HI":"15","ID":"16","IL":"17",
    "IN":"18","IA":"19","KS":"20","KY":"21","LA":"22","ME":"23","MD":"24",
    "MA":"25","MI":"26","MN":"27","MS":"28","MO":"29","MT":"30","NE":"31",
    "NV":"32","NH":"33","NJ":"34","NM":"35","NY":"36","NC":"37","ND":"38",
    "OH":"39","OK":"40","OR":"41","PA":"42","RI":"44","SC":"45","SD":"46",
    "TN":"47","TX":"48","UT":"49","VT":"50","VA":"51","WA":"53","WV":"54",
    "WI":"55","WY":"56","PR":"72",
}

# Plotting palette
COLORS = {
    "red":   "#b5272a",
    "blue":  "#1c3f6e",
    "gold":  "#c17f24",
    "green": "#1a7a4f",
    "grey":  "#8a8680",
    "bg":    "#f5f0e8",
    "card":  "#faf7f2",
    "ink":   "#1a1a1a",
}

# Ensure directories exist
for d in [DATA_RAW, DATA_INTERIM, DATA_PROCESSED,
          RESULTS_P1, RESULTS_P2, FIGURES_P1, FIGURES_P2]:
    d.mkdir(parents=True, exist_ok=True)
